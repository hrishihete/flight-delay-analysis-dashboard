# %% [markdown]
# # Week 4 Airline Average Delay Analysis
#
# Project: Flight Delay Analysis & Dashboard
#
# Goal: identify the top 10 airlines by average delay time and produce bar/scatter chart outputs.

# %% [markdown]
# ## Reproducible Steps
#
# 1. Run `src/clean_delay_data.py` if the cleaned dataset does not exist.
# 2. Run `src/analyze_airline_average_delay.py` from the project root.
# 3. Review `reports/airline_average_delay_analysis.md` and Week 4 screenshots.

# %%
from pathlib import Path
import pandas as pd

project_root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
project_root

# %%
# Run from project root if outputs need to be regenerated:
# !python src/analyze_airline_average_delay.py

# %%
top10 = pd.read_csv(project_root / 'data' / 'processed' / 'top10_airlines_average_delay_2024_01.csv')
top10

# %% [markdown]
# ## Generated Artifacts
#
# - `reports/airline_average_delay_analysis.md`
# - `reports/week4_update.md`
# - `screenshots/week4_top10_airlines_avg_delay_bar.png`
# - `screenshots/week4_airline_avg_delay_scatter.png`
