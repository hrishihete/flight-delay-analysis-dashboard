# %% [markdown]
# # Week 5 Airport-Wise Delay Analysis
#
# Project: Flight Delay Analysis & Dashboard
#
# Goal: analyze airport-wise delay patterns using grouped aggregations.

# %% [markdown]
# ## Reproducible Steps
#
# 1. Run `src/clean_delay_data.py` if the cleaned dataset does not exist.
# 2. Run `src/analyze_airport_delays.py` from the project root.
# 3. Review `reports/airport_delay_analysis.md` and Week 5 screenshots.

# %%
from pathlib import Path
import pandas as pd

project_root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
project_root

# %%
# Run from project root if outputs need to be regenerated:
# !python src/analyze_airport_delays.py

# %%
origin_top10 = pd.read_csv(project_root / 'data' / 'processed' / 'top10_origin_airports_by_avg_delay_2024_01.csv')
origin_top10

# %%
destination_top10 = pd.read_csv(project_root / 'data' / 'processed' / 'top10_destination_airports_by_avg_delay_2024_01.csv')
destination_top10

# %% [markdown]
# ## Generated Artifacts
#
# - `reports/airport_delay_analysis.md`
# - `reports/week5_update.md`
# - `screenshots/week5_top10_origin_airports_avg_delay.png`
# - `screenshots/week5_top10_destination_airports_avg_delay.png`
# - `screenshots/week5_origin_airport_delay_scatter.png`
# - `screenshots/week5_top10_origin_airports_nas_delay.png`
