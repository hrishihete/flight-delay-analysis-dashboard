# %% [markdown]
# # Week 3 Delay Cause Analysis
#
# Project: Flight Delay Analysis & Dashboard
#
# Goal: analyze BTS delay causes: carrier, weather, NAS, security, and late aircraft.

# %% [markdown]
# ## Reproducible Steps
#
# 1. Run `src/clean_delay_data.py` if the cleaned dataset does not exist.
# 2. Run `src/analyze_delay_causes.py` from the project root.
# 3. Review `reports/delay_cause_analysis.md` and the Week 3 screenshots.

# %%
from pathlib import Path
import pandas as pd

project_root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
project_root

# %%
# Run from project root if outputs need to be regenerated:
# !python src/analyze_delay_causes.py

# %%
summary = pd.read_csv(project_root / 'data' / 'processed' / 'delay_cause_summary_2024_01.csv')
summary

# %%
airline = pd.read_csv(project_root / 'data' / 'processed' / 'delay_cause_by_airline_2024_01.csv')
airline.head(10)

# %% [markdown]
# ## Generated Artifacts
#
# - `reports/delay_cause_analysis.md`
# - `reports/week3_update.md`
# - `screenshots/week3_total_delay_minutes_by_cause.png`
# - `screenshots/week3_delay_cause_share.png`
# - `screenshots/week3_top_airlines_carrier_delay.png`
# - `screenshots/week3_delay_cause_time_heatmap.png`
